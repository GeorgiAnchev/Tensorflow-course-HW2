# %% [markdown]
# Deep Learning with Tensorflow
# =============
#
# Assignment II
# ------------
#
# During one of the lectures in [Lab 1](https://deep-learning-su.github.io/labs/lab-1/) we trained fully connected network to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.
#
# For this exercise, you would need the `notMNIST.pickle` created in `Lab 1`. You can obtain it by rerunning the given paragraphs without having to solve the problems (although it is highly recommended to do it if you haven't already).

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# ## Problem 1
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.
#
# Edit the snippet bellow by changing the `model` function.
#
# ### 1.1 - Define the model
# Implement the `model` function bellow. Take a look at the following TF functions:
# - **tf.nn.conv2d(X,W1, strides = [1,s,s,1], padding = 'SAME'):** given an input $X$ and a group of filters $W1$, this function convolves $W1$'s filters on X. The third input ([1,f,f,1]) represents the strides for each dimension of the input (m, n_H_prev, n_W_prev, n_C_prev). You can read the full documentation [here](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d)
# - **tf.nn.relu(Z1):** computes the elementwise ReLU of Z1 (which can be any shape). You can read the full documentation [here.](https://www.tensorflow.org/api_docs/python/tf/nn/relu)
#
# ### 1.2 - Compute loss
#
# Implement the `compute_loss` function below. You might find these two functions helpful:
#
# - **tf.nn.softmax_cross_entropy_with_logits(logits = Z3, labels = Y):** computes the softmax entropy loss. This function both computes the softmax activation function as well as the resulting loss. You can check the full documentation  [here.](https://www.tensorflow.org/api_docs/python/tf/nn/softmax_cross_entropy_with_logits)
# - **tf.reduce_mean:** computes the mean of elements across dimensions of a tensor. Use this to sum the losses over all the examples to get the overall cost. You can check the full documentation [here.](https://www.tensorflow.org/api_docs/python/tf/reduce_mean)

# %%
batch_size = 1000 #16
patch_size = 5
depth = 64 # Number of filters?
num_hidden = 64 # Size of the fully connected layer?

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
        
  shape1 = [patch_size, patch_size, num_channels, depth]
  W1 = tf.Variable(tf.truncated_normal(shape1, stddev=0.1))
  b1 = tf.Variable(tf.zeros([depth]))

  shape2 = [patch_size, patch_size, depth, depth]
  W2 = tf.Variable(tf.truncated_normal(shape2, stddev=0.1))
  b2 = tf.Variable(tf.zeros([depth]))

  shape3 = [ depth * 7 * 7, num_hidden]
  W3 = tf.Variable(tf.truncated_normal(shape3, stddev=0.1))
  b3 = tf.Variable(tf.zeros([num_hidden]))

  shape4 = [num_hidden, num_labels]
  W4 = tf.Variable(tf.truncated_normal(shape4, stddev=0.1))
  b4 = tf.Variable(tf.zeros([num_labels]))

  # Model.
  def model(data):
    # define a simple network with 
    # * 2 convolutional layers with 5x5 filters each using stride 2 and zero padding
    # * one fully connected layer
    # return the logits (last layer)
    
    
    s = 2 # strides
    layer1 = tf.nn.conv2d(data, W1, strides = [1,s,s,1], padding = 'SAME')
    activ_layer_1 = tf.nn.relu(layer1 + b1)
    #print(activ_layer_1.shape) (16, 14, 14, 16)
    
    
    layer2 = tf.nn.conv2d(activ_layer_1, W2, strides = [1,s,s,1], padding = 'SAME')
    activ_layer_2 = tf.nn.relu(layer2 + b2)
    #print(activ_layer_2.shape) #(16, 7, 7, 16)
    
    layer_shape = activ_layer_2.get_shape()
    num_features = layer_shape[1:4].num_elements()
    layer_flat = tf.reshape(activ_layer_2, [-1, num_features])
    #print(layer_flat.shape) #(16, 784)
    
    layer3 = tf.matmul(layer_flat, W3)
    activ_layer_3 = tf.nn.relu(layer3 + b3)
    #print(activ_layer_3.shape)
    
    logits = tf.matmul(activ_layer_3, W4) + b4
    #print(logits.shape)
    
    #print()
    return logits

  def compute_loss(labels, logits):
    return tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits = logits, labels = labels))
  
  # Training computation.
  logits = model(tf_train_dataset)
  #print(logits.shape)
  loss = compute_loss(tf_train_labels, logits)
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %% [markdown]
# ### 1.3 - Measure the accuracy and tune your model
#
# Run the snippet bellow to measure the accuracy of your model. Try to achieve a test accuracy of around 80%. Iterate on the filters size.

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.866762
# Minibatch accuracy: 7.7%
# Validation accuracy: 11.8%
# Minibatch loss at step 50: 0.850292
# Minibatch accuracy: 76.8%
# Validation accuracy: 77.1%
# Minibatch loss at step 100: 0.643908
# Minibatch accuracy: 81.7%
# Validation accuracy: 79.8%
# Minibatch loss at step 150: 0.622491
# Minibatch accuracy: 81.5%
# Validation accuracy: 80.7%
# Minibatch loss at step 200: 0.549881
# Minibatch accuracy: 84.5%
# Validation accuracy: 81.9%
# Minibatch loss at step 250: 0.617479
# Minibatch accuracy: 81.8%
# Validation accuracy: 82.5%
# Minibatch loss at step 300: 0.518091
# Minibatch accuracy: 85.1%
# Validation accuracy: 82.3%
# Minibatch loss at step 350: 0.596062
# Minibatch accuracy: 82.9%
# Validation accuracy: 82.9%
# Minibatch loss at step 400: 0.492881
# Minibatch accuracy: 85.6%
# Validation accuracy: 83.4%
# Minibatch loss at step 450: 0.590239
# Minibatch accuracy: 82.8%
# Validation accuracy: 83.7%
# Minibatch loss at step 500: 0.474152
# Minibatch accuracy: 86.5%
# Validation accuracy: 84.0%
# Minibatch loss at step 550: 0.509281
# Minibatch accuracy: 86.4%
# Validation accuracy: 84.3%
# Minibatch loss at step 600: 0.513907
# Minibatch accuracy: 84.7%
# Validation accuracy: 84.4%
# Minibatch loss at step 650: 0.440215
# Minibatch accuracy: 86.9%
# Validation accuracy: 84.8%
# Minibatch loss at step 700: 0.541720
# Minibatch accuracy: 85.0%
# Validation accuracy: 84.8%
# Minibatch loss at step 750: 0.491665
# Minibatch accuracy: 86.2%
# Validation accuracy: 85.1%
# Minibatch loss at step 800: 0.500664
# Minibatch accuracy: 85.9%
# Validation accuracy: 85.2%
# Minibatch loss at step 850: 0.463505
# Minibatch accuracy: 86.3%
# Validation accuracy: 85.5%
# Minibatch loss at step 900: 0.512499
# Minibatch accuracy: 84.5%
# Validation accuracy: 85.7%
# Minibatch loss at step 950: 0.502900
# Minibatch accuracy: 84.1%
# Validation accuracy: 85.8%
# Minibatch loss at step 1000: 0.447812
# Minibatch accuracy: 86.6%
# Validation accuracy: 86.0%
# Test accuracy: 92.5%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 100 #16
patch_size = 5
depth = 64 # Number of filters?
num_hidden = 64 # Size of the fully connected layer?
graph2 = tf.Graph()

with graph2.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
        
  shape1 = [patch_size, patch_size, num_channels, depth]
  W1 = tf.Variable(tf.truncated_normal(shape1, stddev=0.1))
  b1 = tf.Variable(tf.zeros([depth]))

  shape2 = [patch_size, patch_size, depth, depth]
  W2 = tf.Variable(tf.truncated_normal(shape2, stddev=0.1))
  b2 = tf.Variable(tf.zeros([depth]))

  shape3 = [ depth * 7 * 7, num_hidden]
  W3 = tf.Variable(tf.truncated_normal(shape3, stddev=0.1))
  b3 = tf.Variable(tf.zeros([num_hidden]))

  shape4 = [num_hidden, num_labels]
  W4 = tf.Variable(tf.truncated_normal(shape4, stddev=0.1))
  b4 = tf.Variable(tf.zeros([num_labels]))

  s = 1 # strides of convolution
  k_size = 2 # kernel size
  k_strides = 2 # kernel strides

  # Model.
  def model(data):
    # define a simple network with 
    # * 2 convolutional layers with 5x5 filters each using stride 1 and zero ,relu, max pooling
    # * one fully connected layer
    # return the logits (last layer)
    
    layer1 = tf.nn.conv2d(data, W1, strides = [1,s,s,1], padding = 'SAME')
    #print(layer1.shape)
    pool_layer_1 = tf.nn.max_pool(layer1, ksize=[1, k_size, k_size, 1], strides=[1, k_strides, k_strides, 1], padding='SAME')
    #print(pool_layer_1.shape)
    activ_layer_1 = tf.nn.relu(pool_layer_1 + b1)
    #print(activ_layer_1.shape) 
    #print("lalalala")
    
    layer2 = tf.nn.conv2d(activ_layer_1, W2, strides = [1,s,s,1], padding = 'SAME')
    pool_layer_2 = tf.nn.max_pool(layer2, ksize=[1, k_size, k_size, 1], strides=[1, k_strides, k_strides, 1], padding='SAME')
    activ_layer_2 = tf.nn.relu(pool_layer_2 + b2)
    #print(activ_layer_2.shape)
    
    layer_shape = activ_layer_2.get_shape()
    num_features = layer_shape[1:4].num_elements()
    layer_flat = tf.reshape(activ_layer_2, [-1, num_features])
    #print(layer_flat.shape)
    
    layer3 = tf.matmul(layer_flat, W3)
    activ_layer_3 = tf.nn.relu(layer3 + b3)
    #print(activ_layer_3.shape)
    
    logits = tf.matmul(activ_layer_3, W4) + b4
    #print(logits.shape)
    
    #print()
    return logits

  def compute_loss(labels, logits):
    return tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits = logits, labels = labels))
  
  # Training computation.
  logits = model(tf_train_dataset)
  #print(logits.shape)
  loss = compute_loss(tf_train_labels, logits)
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph2) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.731841
# Minibatch accuracy: 9.0%
# Validation accuracy: 13.0%
# Minibatch loss at step 50: 0.753579
# Minibatch accuracy: 77.0%
# Validation accuracy: 77.1%
# Minibatch loss at step 100: 0.655300
# Minibatch accuracy: 79.0%
# Validation accuracy: 80.6%
# Minibatch loss at step 150: 0.616575
# Minibatch accuracy: 83.0%
# Validation accuracy: 81.6%
# Minibatch loss at step 200: 0.681050
# Minibatch accuracy: 80.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 250: 0.491098
# Minibatch accuracy: 90.0%
# Validation accuracy: 83.8%
# Minibatch loss at step 300: 0.614439
# Minibatch accuracy: 83.0%
# Validation accuracy: 83.6%
# Minibatch loss at step 350: 0.525841
# Minibatch accuracy: 84.0%
# Validation accuracy: 84.1%
# Minibatch loss at step 400: 0.584054
# Minibatch accuracy: 83.0%
# Validation accuracy: 84.5%
# Minibatch loss at step 450: 0.603565
# Minibatch accuracy: 86.0%
# Validation accuracy: 85.3%
# Minibatch loss at step 500: 0.677390
# Minibatch accuracy: 80.0%
# Validation accuracy: 85.6%
# Minibatch loss at step 550: 0.710323
# Minibatch accuracy: 81.0%
# Validation accuracy: 85.8%
# Minibatch loss at step 600: 0.535052
# Minibatch accuracy: 86.0%
# Validation accuracy: 85.7%
# Minibatch loss at step 650: 0.519372
# Minibatch accuracy: 87.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 700: 0.398832
# Minibatch accuracy: 90.0%
# Validation accuracy: 86.1%
# Minibatch loss at step 750: 0.452836
# Minibatch accuracy: 87.0%
# Validation accuracy: 86.2%
# Minibatch loss at step 800: 0.673179
# Minibatch accuracy: 82.0%
# Validation accuracy: 85.8%
# Minibatch loss at step 850: 0.467522
# Minibatch accuracy: 89.0%
# Validation accuracy: 86.3%
# Minibatch loss at step 900: 0.541792
# Minibatch accuracy: 80.0%
# Validation accuracy: 86.5%
# Minibatch loss at step 950: 0.344000
# Minibatch accuracy: 90.0%
# Validation accuracy: 86.5%
# Minibatch loss at step 1000: 0.531403
# Minibatch accuracy: 84.0%
# Validation accuracy: 86.5%
# Test accuracy: 92.9%

# %% [markdown]
# ---
# Problem 3
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---
# Three convolutional layers, the first two with max pooling, then two fully connected layers with dropout.
# Got test accuracy: 94.3%

# %%
batch_size = 500 #16
patch_size = 5
depth = 50 # Number of filters?
num_hidden_1 = 80 # 
num_hidden_2 = 50 # 

s = 1 # strides of convolution
k_size = 2 # kernel size
k_strides = 2 # kernel strides
keep_rate = 0.5

graph3 = tf.Graph()

with graph3.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
        
  W1 = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
  b1 = tf.Variable(tf.zeros([depth]))

  W2 = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
  b2 = tf.Variable(tf.zeros([depth]))
    
  W3 = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
  b3 = tf.Variable(tf.zeros([depth]))

  W4 = tf.Variable(tf.truncated_normal([ depth * 7 * 7, num_hidden_1], stddev=0.1))
  b4 = tf.Variable(tf.zeros([num_hidden_1]))

  W5 = tf.Variable(tf.truncated_normal([num_hidden_1, num_hidden_2], stddev=0.1))
  b5 = tf.Variable(tf.zeros([num_hidden_2]))

  W6 = tf.Variable(tf.truncated_normal([num_hidden_2, num_labels], stddev=0.1))
  b6 = tf.Variable(tf.zeros([num_labels]))

  # Model.
  def model(data):
    # define a simple network with 
    # * 3 convolutional layers with 5x5 filters each using stride 1 and zero padding, relu, 2 max poolings
    # * one fully connected layer
    # return the logits (last layer)
    
    layer1 = tf.nn.conv2d(data, W1, strides = [1,s,s,1], padding = 'SAME')
    pool_layer_1 = tf.nn.max_pool(layer1, ksize=[1, k_size, k_size, 1], strides=[1, k_strides, k_strides, 1], padding='SAME')
    activ_layer_1 = tf.nn.relu(tf.add(pool_layer_1, b1))
    
    layer2 = tf.nn.conv2d(activ_layer_1, W2, strides = [1,s,s,1], padding = 'SAME')
    pool_layer_2 = tf.nn.max_pool(layer2, ksize=[1, k_size, k_size, 1], strides=[1, k_strides, k_strides, 1], padding='SAME')
    activ_layer_2 = tf.nn.relu(tf.add(pool_layer_2, b2))
    
    layer3 = tf.nn.conv2d(activ_layer_2, W3, strides = [1,s,s,1], padding = 'SAME')
    activ_layer_3 = tf.nn.relu(tf.add(layer3, b3))
    
    layer_shape = activ_layer_3.get_shape()
    num_features = layer_shape[1:4].num_elements()
    layer_flat = tf.reshape(activ_layer_3, [-1, num_features])

    layer4 = tf.matmul(layer_flat, W4)
    activ_layer_4 = tf.nn.relu(tf.add(layer4, b4))
    dropout_4 = tf.nn.dropout(activ_layer_4, keep_rate)

    layer5 = tf.matmul(activ_layer_4, W5)
    activ_layer_5 = tf.nn.relu(tf.add(layer5, b5))
    dropout_5 = tf.nn.dropout(activ_layer_5, keep_rate)
    
    logits = tf.add(tf.matmul(dropout_5, W6), b6)

    return logits

  def compute_loss(labels, logits):
    return tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits = logits, labels = labels))
  
  # Training computation.
  logits = model(tf_train_dataset)
  #print(logits.shape)
  loss = compute_loss(tf_train_labels, logits)
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.03).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 7001

with tf.Session(graph=graph3) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.604882
# Minibatch accuracy: 13.4%
# Validation accuracy: 13.2%
# Minibatch loss at step 50: 1.401633
# Minibatch accuracy: 54.8%
# Validation accuracy: 57.1%
# Minibatch loss at step 100: 1.010350
# Minibatch accuracy: 70.4%
# Validation accuracy: 68.6%
# Minibatch loss at step 150: 0.932864
# Minibatch accuracy: 72.4%
# Validation accuracy: 74.2%
# Minibatch loss at step 200: 0.808753
# Minibatch accuracy: 77.0%
# Validation accuracy: 76.9%
# Minibatch loss at step 250: 0.678382
# Minibatch accuracy: 80.4%
# Validation accuracy: 77.6%
# Minibatch loss at step 300: 0.717673
# Minibatch accuracy: 77.6%
# Validation accuracy: 78.2%
# Minibatch loss at step 350: 0.816342
# Minibatch accuracy: 76.8%
# Validation accuracy: 79.6%
# Minibatch loss at step 400: 0.669786
# Minibatch accuracy: 80.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 450: 0.652294
# Minibatch accuracy: 83.2%
# Validation accuracy: 80.0%
# Minibatch loss at step 500: 0.645164
# Minibatch accuracy: 82.4%
# Validation accuracy: 80.8%
# Minibatch loss at step 550: 0.601048
# Minibatch accuracy: 81.4%
# Validation accuracy: 81.3%
# Minibatch loss at step 600: 0.569816
# Minibatch accuracy: 84.6%
# Validation accuracy: 82.0%
# Minibatch loss at step 650: 0.561975
# Minibatch accuracy: 82.6%
# Validation accuracy: 81.7%
# Minibatch loss at step 700: 0.580584
# Minibatch accuracy: 83.6%
# Validation accuracy: 81.8%
# Minibatch loss at step 750: 0.577945
# Minibatch accuracy: 83.0%
# Validation accuracy: 81.9%
# Minibatch loss at step 800: 0.507235
# Minibatch accuracy: 85.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 850: 0.550080
# Minibatch accuracy: 84.0%
# Validation accuracy: 83.1%
# Minibatch loss at step 900: 0.540624
# Minibatch accuracy: 84.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 950: 0.594463
# Minibatch accuracy: 81.6%
# Validation accuracy: 83.0%
# Minibatch loss at step 1000: 0.517008
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.7%
# Minibatch loss at step 1050: 0.566787
# Minibatch accuracy: 84.2%
# Validation accuracy: 83.6%
# Minibatch loss at step 1100: 0.507568
# Minibatch accuracy: 84.8%
# Validation accuracy: 83.4%
# Minibatch loss at step 1150: 0.462843
# Minibatch accuracy: 85.8%
# Validation accuracy: 84.3%
# Minibatch loss at step 1200: 0.519504
# Minibatch accuracy: 86.2%
# Validation accuracy: 84.4%
# Minibatch loss at step 1250: 0.614961
# Minibatch accuracy: 83.4%
# Validation accuracy: 84.3%
# Minibatch loss at step 1300: 0.527261
# Minibatch accuracy: 83.4%
# Validation accuracy: 84.5%
# Minibatch loss at step 1350: 0.527577
# Minibatch accuracy: 85.2%
# Validation accuracy: 84.6%
# Minibatch loss at step 1400: 0.424177
# Minibatch accuracy: 88.0%
# Validation accuracy: 84.9%
# Minibatch loss at step 1450: 0.465029
# Minibatch accuracy: 85.8%
# Validation accuracy: 85.1%
# Minibatch loss at step 1500: 0.552294
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.6%
# Minibatch loss at step 1550: 0.529852
# Minibatch accuracy: 83.8%
# Validation accuracy: 85.1%
# Minibatch loss at step 1600: 0.408463
# Minibatch accuracy: 87.0%
# Validation accuracy: 85.0%
# Minibatch loss at step 1650: 0.468038
# Minibatch accuracy: 86.2%
# Validation accuracy: 84.8%
# Minibatch loss at step 1700: 0.574791
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 1750: 0.475746
# Minibatch accuracy: 85.6%
# Validation accuracy: 85.5%
# Minibatch loss at step 1800: 0.413648
# Minibatch accuracy: 87.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 1850: 0.400970
# Minibatch accuracy: 87.4%
# Validation accuracy: 85.4%
# Minibatch loss at step 1900: 0.439831
# Minibatch accuracy: 86.0%
# Validation accuracy: 85.7%
# Minibatch loss at step 1950: 0.372847
# Minibatch accuracy: 87.8%
# Validation accuracy: 85.3%
# Minibatch loss at step 2000: 0.385493
# Minibatch accuracy: 87.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 2050: 0.391902
# Minibatch accuracy: 89.4%
# Validation accuracy: 85.7%
# Minibatch loss at step 2100: 0.448830
# Minibatch accuracy: 86.8%
# Validation accuracy: 86.0%
# Minibatch loss at step 2150: 0.419039
# Minibatch accuracy: 87.8%
# Validation accuracy: 85.9%
# Minibatch loss at step 2200: 0.467714
# Minibatch accuracy: 86.8%
# Validation accuracy: 85.8%
# Minibatch loss at step 2250: 0.479991
# Minibatch accuracy: 84.2%
# Validation accuracy: 85.8%
# Minibatch loss at step 2300: 0.433410
# Minibatch accuracy: 86.6%
# Validation accuracy: 86.2%
# Minibatch loss at step 2350: 0.443872
# Minibatch accuracy: 86.2%
# Validation accuracy: 86.2%
# Minibatch loss at step 2400: 0.497399
# Minibatch accuracy: 85.2%
# Validation accuracy: 86.0%
# Minibatch loss at step 2450: 0.413180
# Minibatch accuracy: 86.6%
# Validation accuracy: 86.3%
# Minibatch loss at step 2500: 0.407189
# Minibatch accuracy: 88.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 2550: 0.448404
# Minibatch accuracy: 86.0%
# Validation accuracy: 86.3%
# Minibatch loss at step 2600: 0.487239
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.1%
# Minibatch loss at step 2650: 0.483104
# Minibatch accuracy: 86.2%
# Validation accuracy: 86.0%
# Minibatch loss at step 2700: 0.444353
# Minibatch accuracy: 85.4%
# Validation accuracy: 86.5%
# Minibatch loss at step 2750: 0.434941
# Minibatch accuracy: 88.0%
# Validation accuracy: 86.2%
# Minibatch loss at step 2800: 0.403044
# Minibatch accuracy: 88.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 2850: 0.355359
# Minibatch accuracy: 88.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 2900: 0.326880
# Minibatch accuracy: 89.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 2950: 0.368151
# Minibatch accuracy: 89.2%
# Validation accuracy: 86.8%
# Minibatch loss at step 3000: 0.441336
# Minibatch accuracy: 86.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 3050: 0.425927
# Minibatch accuracy: 87.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 3100: 0.363551
# Minibatch accuracy: 88.4%
# Validation accuracy: 86.6%
# Minibatch loss at step 3150: 0.362193
# Minibatch accuracy: 90.4%
# Validation accuracy: 86.8%
# Minibatch loss at step 3200: 0.421159
# Minibatch accuracy: 88.6%
# Validation accuracy: 86.6%
# Minibatch loss at step 3250: 0.421960
# Minibatch accuracy: 89.0%
# Validation accuracy: 86.9%
# Minibatch loss at step 3300: 0.366925
# Minibatch accuracy: 88.4%
# Validation accuracy: 86.9%
# Minibatch loss at step 3350: 0.456609
# Minibatch accuracy: 86.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 3400: 0.476606
# Minibatch accuracy: 85.6%
# Validation accuracy: 86.8%
# Minibatch loss at step 3450: 0.412962
# Minibatch accuracy: 89.0%
# Validation accuracy: 87.1%
# Minibatch loss at step 3500: 0.394075
# Minibatch accuracy: 87.2%
# Validation accuracy: 86.9%
# Minibatch loss at step 3550: 0.386108
# Minibatch accuracy: 88.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 3600: 0.410145
# Minibatch accuracy: 86.8%
# Validation accuracy: 86.9%
# Minibatch loss at step 3650: 0.376202
# Minibatch accuracy: 87.6%
# Validation accuracy: 87.2%
# Minibatch loss at step 3700: 0.400253
# Minibatch accuracy: 88.2%
# Validation accuracy: 87.3%
# Minibatch loss at step 3750: 0.486336
# Minibatch accuracy: 85.2%
# Validation accuracy: 86.9%
# Minibatch loss at step 3800: 0.403806
# Minibatch accuracy: 89.2%
# Validation accuracy: 87.1%
# Minibatch loss at step 3850: 0.401507
# Minibatch accuracy: 89.2%
# Validation accuracy: 87.1%
# Minibatch loss at step 3900: 0.460628
# Minibatch accuracy: 85.6%
# Validation accuracy: 87.4%
# Minibatch loss at step 3950: 0.364560
# Minibatch accuracy: 88.4%
# Validation accuracy: 87.2%
# Minibatch loss at step 4000: 0.432580
# Minibatch accuracy: 87.2%
# Validation accuracy: 87.5%
# Minibatch loss at step 4050: 0.567015
# Minibatch accuracy: 85.0%
# Validation accuracy: 87.1%
# Minibatch loss at step 4100: 0.460272
# Minibatch accuracy: 85.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 4150: 0.380145
# Minibatch accuracy: 88.4%
# Validation accuracy: 87.5%
# Minibatch loss at step 4200: 0.413573
# Minibatch accuracy: 88.6%
# Validation accuracy: 87.3%
# Minibatch loss at step 4250: 0.390965
# Minibatch accuracy: 86.0%
# Validation accuracy: 87.3%
# Minibatch loss at step 4300: 0.372966
# Minibatch accuracy: 88.4%
# Validation accuracy: 87.5%
# Minibatch loss at step 4350: 0.453895
# Minibatch accuracy: 87.2%
# Validation accuracy: 87.2%
# Minibatch loss at step 4400: 0.349141
# Minibatch accuracy: 89.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 4450: 0.450423
# Minibatch accuracy: 88.0%
# Validation accuracy: 87.5%
# Minibatch loss at step 4500: 0.384738
# Minibatch accuracy: 86.6%
# Validation accuracy: 87.7%
# Minibatch loss at step 4550: 0.394081
# Minibatch accuracy: 90.0%
# Validation accuracy: 87.5%
# Minibatch loss at step 4600: 0.354296
# Minibatch accuracy: 89.4%
# Validation accuracy: 87.8%
# Minibatch loss at step 4650: 0.418879
# Minibatch accuracy: 87.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 4700: 0.428881
# Minibatch accuracy: 88.4%
# Validation accuracy: 87.3%
# Minibatch loss at step 4750: 0.323874
# Minibatch accuracy: 91.6%
# Validation accuracy: 87.6%
# Minibatch loss at step 4800: 0.386304
# Minibatch accuracy: 89.0%
# Validation accuracy: 87.5%
# Minibatch loss at step 4850: 0.339717
# Minibatch accuracy: 88.8%
# Validation accuracy: 87.9%
# Minibatch loss at step 4900: 0.317064
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.8%
# Minibatch loss at step 4950: 0.485465
# Minibatch accuracy: 86.4%
# Validation accuracy: 87.6%
# Minibatch loss at step 5000: 0.344998
# Minibatch accuracy: 88.6%
# Validation accuracy: 88.2%
# Minibatch loss at step 5050: 0.352144
# Minibatch accuracy: 88.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 5100: 0.319586
# Minibatch accuracy: 90.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 5150: 0.406706
# Minibatch accuracy: 88.4%
# Validation accuracy: 87.8%
# Minibatch loss at step 5200: 0.357335
# Minibatch accuracy: 88.6%
# Validation accuracy: 87.6%
# Minibatch loss at step 5250: 0.354935
# Minibatch accuracy: 89.6%
# Validation accuracy: 88.0%
# Minibatch loss at step 5300: 0.383524
# Minibatch accuracy: 88.4%
# Validation accuracy: 88.0%
# Minibatch loss at step 5350: 0.366315
# Minibatch accuracy: 89.2%
# Validation accuracy: 87.7%
# Minibatch loss at step 5400: 0.358374
# Minibatch accuracy: 88.6%
# Validation accuracy: 87.9%
# Minibatch loss at step 5450: 0.330655
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 5500: 0.423179
# Minibatch accuracy: 87.2%
# Validation accuracy: 88.0%
# Minibatch loss at step 5550: 0.331936
# Minibatch accuracy: 90.2%
# Validation accuracy: 88.2%
# Minibatch loss at step 5600: 0.431692
# Minibatch accuracy: 87.2%
# Validation accuracy: 87.8%
# Minibatch loss at step 5650: 0.403408
# Minibatch accuracy: 89.6%
# Validation accuracy: 87.9%
# Minibatch loss at step 5700: 0.413174
# Minibatch accuracy: 87.6%
# Validation accuracy: 88.0%
# Minibatch loss at step 5750: 0.340513
# Minibatch accuracy: 88.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 5800: 0.316809
# Minibatch accuracy: 90.4%
# Validation accuracy: 87.7%
# Minibatch loss at step 5850: 0.351363
# Minibatch accuracy: 89.2%
# Validation accuracy: 88.1%
# Minibatch loss at step 5900: 0.354419
# Minibatch accuracy: 89.0%
# Validation accuracy: 88.2%
# Minibatch loss at step 5950: 0.368777
# Minibatch accuracy: 90.0%
# Validation accuracy: 88.1%
# Minibatch loss at step 6000: 0.412205
# Minibatch accuracy: 88.0%
# Validation accuracy: 88.2%
# Minibatch loss at step 6050: 0.333382
# Minibatch accuracy: 89.6%
# Validation accuracy: 88.3%
# Minibatch loss at step 6100: 0.314913
# Minibatch accuracy: 89.2%
# Validation accuracy: 88.2%
# Minibatch loss at step 6150: 0.423555
# Minibatch accuracy: 88.6%
# Validation accuracy: 88.2%
# Minibatch loss at step 6200: 0.376206
# Minibatch accuracy: 88.4%
# Validation accuracy: 87.9%
# Minibatch loss at step 6250: 0.347007
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.3%
# Minibatch loss at step 6300: 0.365538
# Minibatch accuracy: 88.4%
# Validation accuracy: 88.3%
# Minibatch loss at step 6350: 0.319017
# Minibatch accuracy: 90.4%
# Validation accuracy: 88.3%
# Minibatch loss at step 6400: 0.324277
# Minibatch accuracy: 90.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 6450: 0.306160
# Minibatch accuracy: 89.2%
# Validation accuracy: 88.1%
# Minibatch loss at step 6500: 0.389479
# Minibatch accuracy: 88.2%
# Validation accuracy: 88.3%
# Minibatch loss at step 6550: 0.319211
# Minibatch accuracy: 91.4%
# Validation accuracy: 88.4%
# Minibatch loss at step 6600: 0.388157
# Minibatch accuracy: 89.2%
# Validation accuracy: 88.4%
# Minibatch loss at step 6650: 0.449477
# Minibatch accuracy: 87.4%
# Validation accuracy: 88.6%
# Minibatch loss at step 6700: 0.372722
# Minibatch accuracy: 87.4%
# Validation accuracy: 88.3%
# Minibatch loss at step 6750: 0.321583
# Minibatch accuracy: 90.4%
# Validation accuracy: 88.5%
# Minibatch loss at step 6800: 0.339167
# Minibatch accuracy: 90.0%
# Validation accuracy: 88.5%
# Minibatch loss at step 6850: 0.345697
# Minibatch accuracy: 88.6%
# Validation accuracy: 88.5%
# Minibatch loss at step 6900: 0.379009
# Minibatch accuracy: 87.4%
# Validation accuracy: 88.4%
# Minibatch loss at step 6950: 0.379137
# Minibatch accuracy: 87.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 7000: 0.353847
# Minibatch accuracy: 88.6%
# Validation accuracy: 88.4%
# Test accuracy: 94.3%
